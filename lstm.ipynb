# %% [markdown]
# ## Long Short-Term Memory

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Helper functions
from helper_functions import get_bitcoin_df, create_dataset_with_look_back

# Needed imports
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import math
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# Get the dataframe
btc_df = get_bitcoin_df()
btc_df.head()
# Out:
#         date         open         high          low        close  volume_btc  \
# 0 2017-01-01   977.256602   977.385233   977.132620   977.276060    4.760662
# 1 2017-01-02  1012.267604  1012.517181  1011.988826  1012.273903    5.671792
# 2 2017-01-03  1020.001535  1020.226840  1019.794437  1020.040472    6.312263
# 3 2017-01-04  1076.558840  1077.271167  1075.572542  1076.553639   14.973928
# 4 2017-01-05  1043.608646  1044.905549  1042.094125  1043.547951   25.013098
#
#      volume_usd
# 0   4701.831942
# 1   5747.243606
# 2   6442.176792
# 3  16303.129214
# 4  25132.509465

# %%
# Select data range
bitcoin_dataframe = btc_df[(btc_df['date'] < '2022-02-01') & (btc_df['date'] > '2019-12-31')]

# %% [markdown]
# ### Non-Stationary data

# %%
# Prepare data
univariate_df = bitcoin_dataframe[['date', 'close']].copy()

close_only_df = univariate_df.filter(['close'])
dataset = close_only_df.values

scaler = MinMaxScaler(feature_range=(0, 1))
# We shouldn't do this as we leak information about test dataset
#scaled_data = scaler.fit_transform(dataset)

# %%
# Define train and test size
train_size = int(0.7 * len(univariate_df))
test_size = len(univariate_df) - train_size

# Set look back
look_back = 30

train_unscaled, test_unscaled = dataset[:train_size-look_back, :], dataset[train_size-look_back:, :]
train_scaled = scaler.fit_transform(train_unscaled)
test_scaled = scaler.transform(test_unscaled)

x_train, y_train = create_dataset_with_look_back(train_scaled, look_back)
x_test, y_test = create_dataset_with_look_back(test_scaled, look_back)

# Reshape input to be [samples, time steps, features]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

print("Train size: ", len(x_train), " test size: ", len(x_test))
# Out:
# Train size:  473  test size:  229

# %%
# Building the model
model = Sequential()
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(x_train, y_train, batch_size=32, epochs=200)

model.summary()
# Out:
# Epoch 1/200
# 15/15 [==============================] - 5s 30ms/step - loss: 0.0255
# Epoch 2/200
# 15/15 [==============================] - 1s 38ms/step - loss: 0.0032
# Epoch 3/200
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0020
# Epoch 4/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0017
# Epoch 5/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0016
# Epoch 6/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0018
# Epoch 7/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0016
# Epoch 8/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0016
# Epoch 9/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0015
# Epoch 10/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0014
# Epoch 11/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0014
# Epoch 12/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0014
# Epoch 13/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0014
# Epoch 14/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0014
# Epoch 15/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0014
# Epoch 16/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0013
# Epoch 17/200
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0013
# Epoch 18/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0013
# Epoch 19/200
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0012
# Epoch 20/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0011
# Epoch 21/200
# 15/15 [==============================] - 1s 34ms/step - loss: 0.0011
# Epoch 22/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0011
# Epoch 23/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0012
# Epoch 24/200
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 25/200
# 15/15 [==============================] - 0s 33ms/step - loss: 9.9028e-04
# Epoch 26/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0011
# Epoch 27/200
# 15/15 [==============================] - 0s 27ms/step - loss: 8.3366e-04
# Epoch 28/200
# 15/15 [==============================] - 0s 28ms/step - loss: 7.8800e-04
# Epoch 29/200
# 15/15 [==============================] - 1s 33ms/step - loss: 7.9352e-04
# Epoch 30/200
# 15/15 [==============================] - 1s 33ms/step - loss: 9.2935e-04
# Epoch 31/200
# 15/15 [==============================] - 1s 45ms/step - loss: 8.5871e-04
# Epoch 32/200
# 15/15 [==============================] - 0s 31ms/step - loss: 8.9353e-04
# Epoch 33/200
200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.0927e-04
# Epoch 199/200
# 15/15 [==============================] - 0s 30ms/step - loss: 3.4329e-04
# Epoch 200/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.2777e-04
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 30, 128)           66560
#
#  lstm_13 (LSTM)              (None, 64)                49408
#
#  dense_12 (Dense)            (None, 25)                1625
#
#  dense_13 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 117,619
# Trainable params: 117,619
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Do predictions
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)

# Invert predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform([y_train])

test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# Calculate the scores
score_rmse = np.sqrt(mean_squared_error(y_test[0], test_predict[:,0]))
score_mae = mean_absolute_error(y_test[0], test_predict[:,0])
score_r2 = r2_score(y_test[0], test_predict[:, 0])
print('RMSE: {}, R2: {}'.format(score_rmse, score_r2))
# Out:
# 15/15 [==============================] - 1s 10ms/step
# 8/8 [==============================] - 0s 10ms/step
# RMSE: 1628.1544005453627, R2: 0.9703375178939442

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
x_train_ticks = univariate_df.head(train_size)['date']
y_train = univariate_df.head(train_size)['close']
x_test_ticks = univariate_df.tail(test_size)['date']

fig, ax = plt.subplots(1, figsize=(12, 6))
sns.lineplot(x=x_train_ticks, y=y_train, ax=ax, color=sns.color_palette("muted")[0], label='Train Set', alpha=0.7, linewidth=1.3)
sns.lineplot(x=x_train_ticks[look_back:-look_back], y=train_predict[:, 0], ax=ax, color=sns.color_palette("muted")[3], label='Train Prediction')
sns.lineplot(x=x_test_ticks, y=y_test[0], ax=ax, color=sns.color_palette("muted")[1], label='Ground truth', alpha=0.7, linewidth=1.3)
sns.lineplot(x=x_test_ticks, y=test_predict[:, 0], ax=ax, color=sns.color_palette("muted")[2], label='Prediction')

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}, R2: {score_r2:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='Close', fontsize=14)
# Out:
# /var/folders/5d/h_8336656hb0sql9hqtn3m400000gn/T/ipykernel_63500/2900174513.py:7: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sns.lineplot(x=x_train_ticks[look_back:-look_back], y=train_predict[:, 0], ax=ax, color=sns.color_palette("muted")[3], label='Train Prediction')
# Text(0, 0.5, 'Close')

# %% [markdown]
# ### Stationary data

# %%
# Prepare data
univariate_df = bitcoin_dataframe[['date', 'close']].copy()

# 1st order differencing
univariate_df['close_diff_1'] = np.append([0], np.diff(univariate_df['close']))

close_only_df = univariate_df.filter(['close_diff_1'])
dataset = close_only_df.values

scaler = MinMaxScaler(feature_range=(0, 1))
#scaled_data = scaler.fit_transform(dataset)

# %%
# Define train and test size
train_size = int(0.7 * len(univariate_df))
test_size = len(univariate_df) - train_size

# Set look back
look_back = 30

train_unscaled, test_unscaled = dataset[:train_size-look_back, :], dataset[train_size-look_back:, :]
train_scaled = scaler.fit_transform(train_unscaled)
test_scaled = scaler.transform(test_unscaled)

x_train, y_train = create_dataset_with_look_back(train_scaled, look_back)
x_test, y_test = create_dataset_with_look_back(test_scaled, look_back)

# Reshape input to be [samples, time steps, features]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

print("Train size: ", len(x_train), " test size: ", len(x_test))
# Out:
# Train size:  473  test size:  229

# %%
# Building the model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(x_train, y_train, batch_size=32, epochs=200)

model.summary()
# Out:
# Epoch 1/200
# 15/15 [==============================] - 4s 22ms/step - loss: 0.0591
# Epoch 2/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0118
# Epoch 3/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0094
# Epoch 4/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0084
# Epoch 5/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0083
# Epoch 6/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0083
# Epoch 7/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0081
# Epoch 8/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0082
# Epoch 9/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0082
# Epoch 10/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0083
# Epoch 11/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0081
# Epoch 12/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0081
# Epoch 13/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0082
# Epoch 14/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0081
# Epoch 15/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0083
# Epoch 16/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0081
# Epoch 17/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0082
# Epoch 18/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0083
# Epoch 19/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0083
# Epoch 20/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0084
# Epoch 21/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0083
# Epoch 22/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0082
# Epoch 23/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0083
# Epoch 24/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0081
# Epoch 25/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0083
# Epoch 26/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0088
# Epoch 27/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0083
# Epoch 28/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0084
# Epoch 29/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0083
# Epoch 30/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0083
# Epoch 31/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0084
# Epoch 32/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0080
# Epoch 33/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0082
# Epoch 34/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0085
# Epoch 35/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0082
# Epoch 36/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0080
# Epoch 37/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0081
# Epoch 38/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0084
# Epoch 39/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0079
# Epoch 40/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0083
# Epoch 41/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0082
# Epoch 42/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0081
# Epoch 43/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0080
# Epoch 44/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0081
# Epoch 45/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0083
# Epoch 46/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0082
# Epoch 47/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0079
# Epoch 48/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0080
# Epoch 49/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0086
# Epoch 50/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0082
# Epoch 51/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0082
# Epoch 52/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0087
# Epoch 53/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0090
# Epoch 54/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0081
# Epoch 55/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0081
# Epoch 56/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0082
# Epoch 57/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 58/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 59/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0081
# Epoch 60/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0082
# Epoch 61/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 62/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 63/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 64/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0082
# Epoch 65/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0081
# Epoch 66/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 67/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 68/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0082
# Epoch 69/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 70/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0081
# Epoch 71/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 72/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0084
# Epoch 73/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 74/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 75/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0082
# Epoch 76/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0081
# Epoch 77/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 78/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0082
# Epoch 79/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0082
# Epoch 80/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0080
# Epoch 81/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 82/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0080
# Epoch 83/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 84/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 85/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0079
# Epoch 86/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0082
# Epoch 87/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 88/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0079
# Epoch 89/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0081
# Epoch 90/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0079
# Epoch 91/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0082
# Epoch 92/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0083
# Epoch 93/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 94/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0079
# Epoch 95/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 96/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0080
# Epoch 97/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 98/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0080
# Epoch 99/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0079
# Epoch 100/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0079
# Epoch 101/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0082
# Epoch 102/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0079
# Epoch 103/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 104/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0079
# Epoch 105/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0080
# Epoch 106/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0080
# Epoch 107/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0079
# Epoch 108/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 109/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0079
# Epoch 110/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 111/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0080
# Epoch 112/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0080
# Epoch 113/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0081
# Epoch 114/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 115/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 116/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 117/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0081
# Epoch 118/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0080
# Epoch 119/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0078
# Epoch 120/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0081
# Epoch 121/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0079
# Epoch 122/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0078
# Epoch 123/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0078
# Epoch 124/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 125/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0081
# Epoch 126/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 127/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0078
# Epoch 128/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0079
# Epoch 129/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 130/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 131/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 132/200
# 15/15 [==============================] - 1s 36ms/step - loss: 0.0078
# Epoch 133/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0078
# Epoch 134/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0079
# Epoch 135/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0078
# Epoch 136/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0079
# Epoch 137/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0078
# Epoch 138/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0079
# Epoch 139/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0082
# Epoch 140/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0086
# Epoch 141/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0081
# Epoch 142/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0081
# Epoch 143/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0086
# Epoch 144/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0083
# Epoch 145/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0083
# Epoch 146/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0079
# Epoch 147/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0078
# Epoch 148/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 149/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0079
# Epoch 150/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0078
# Epoch 151/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0081
# Epoch 152/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0081
# Epoch 153/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 154/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0079
# Epoch 155/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 156/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0077
# Epoch 157/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0078
# Epoch 158/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0078
# Epoch 159/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0078
# Epoch 160/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0078
# Epoch 161/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0078
# Epoch 162/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0078
# Epoch 163/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 164/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0078
# Epoch 165/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0078
# Epoch 166/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0078
# Epoch 167/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0078
# Epoch 168/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0079
# Epoch 169/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0078
# Epoch 170/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0078
# Epoch 171/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0080
# Epoch 172/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0080
# Epoch 173/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0078
# Epoch 174/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0078
# Epoch 175/200
# 15/15 [==============================] - 1s 33ms/step - loss: 0.0079
# Epoch 176/200
# 15/15 [==============================] - 1s 37ms/step - loss: 0.0080
# Epoch 177/200
# 15/15 [==============================] - 1s 36ms/step - loss: 0.0079
# Epoch 178/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0078
# Epoch 179/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0079
# Epoch 180/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0080
# Epoch 181/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0078
# Epoch 182/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0082
# Epoch 183/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0077
# Epoch 184/200
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0079
# Epoch 185/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0082
# Epoch 186/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0082
# Epoch 187/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0081
# Epoch 188/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0079
# Epoch 189/200
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0077
# Epoch 190/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0078
# Epoch 191/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0077
# Epoch 192/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0077
# Epoch 193/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0077
# Epoch 194/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0081
# Epoch 195/200
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0080
# Epoch 196/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0079
# Epoch 197/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0080
# Epoch 198/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0077
# Epoch 199/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0077
# Epoch 200/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0081
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 30, 128)           66560
#
#  lstm_15 (LSTM)              (None, 64)                49408
#
#  dense_14 (Dense)            (None, 25)                1625
#
#  dense_15 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 117,619
# Trainable params: 117,619
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Do predictions
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)

# Invert predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform([y_train])

test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# Calculate the scores
score_rmse = np.sqrt(mean_squared_error(y_test[0], test_predict[:,0]))
score_mae = mean_absolute_error(y_test[0], test_predict[:,0])
score_r2 = r2_score(y_test[0], test_predict[:, 0])
print('RMSE: {}, R2: {}'.format(score_rmse, score_r2))
# Out:
# 15/15 [==============================] - 1s 10ms/step
# 8/8 [==============================] - 0s 9ms/step
# RMSE: 1407.6485068399966, R2: -0.09909375550344013

# %%
x_train_ticks = univariate_df.head(train_size)['date']
y_train = univariate_df.head(train_size)['close_diff_1']
x_test_ticks = univariate_df.tail(test_size)['date']

fig, ax = plt.subplots(1, figsize=(12, 6))
sns.lineplot(x=x_train_ticks, y=y_train, ax=ax, color=sns.color_palette("muted")[0], label='Train Set', alpha=0.7, linewidth=1.3)
sns.lineplot(x=x_train_ticks[look_back:-look_back], y=train_predict[:, 0], ax=ax, color=sns.color_palette("muted")[3], label='Train Prediction')
sns.lineplot(x=x_test_ticks, y=y_test[0], ax=ax, color=sns.color_palette("muted")[1], label='Ground truth', alpha=0.7, linewidth=1.3)
sns.lineplot(x=x_test_ticks, y=test_predict[:, 0], ax=ax, color=sns.color_palette("muted")[2], label='Prediction')

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}, R2: {score_r2:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='Close (1st Order Differencing)', fontsize=14)
# Out:
# /var/folders/5d/h_8336656hb0sql9hqtn3m400000gn/T/ipykernel_63500/2646127335.py:7: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sns.lineplot(x=x_train_ticks[look_back:-look_back], y=train_predict[:, 0], ax=ax, color=sns.color_palette("muted")[3], label='Train Prediction')
# Text(0, 0.5, 'Close (1st Order Differencing)')

# %% [markdown]
# Event LSTM who performs very well on Non-Stationary data fails to perform when it comes to Stationary data.
