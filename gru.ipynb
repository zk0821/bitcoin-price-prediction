# %% [markdown]
# ## Gated Recurrent Unit (GRU)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Helper functions
from helper_functions import get_bitcoin_df, create_dataset_with_look_back

# Needed imports
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import math
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU

# %%
# Get the dataframe
btc_df = get_bitcoin_df()
btc_df.head()
# Out:
#         date         open         high  ...        close  volume_btc    volume_usd
# 0 2017-01-01   977.256602   977.385233  ...   977.276060    4.760662   4701.831942
# 1 2017-01-02  1012.267604  1012.517181  ...  1012.273903    5.671792   5747.243606
# 2 2017-01-03  1020.001535  1020.226840  ...  1020.040472    6.312263   6442.176792
# 3 2017-01-04  1076.558840  1077.271167  ...  1076.553639   14.973928  16303.129214
# 4 2017-01-05  1043.608646  1044.905549  ...  1043.547951   25.013098  25132.509465
#
# [5 rows x 7 columns]

# %%
# Select data range
bitcoin_dataframe = btc_df[(btc_df['date'] < '2022-02-01') & (btc_df['date'] > '2019-12-31')]

# %% [markdown]
# ## Non-Stationary data

# %%
# Prepare data
univariate_df = bitcoin_dataframe[['date', 'close']].copy()

close_only_df = univariate_df.filter(['close'])
dataset = close_only_df.values

scaler = MinMaxScaler(feature_range=(0, 1))
# We shouldn't do this as we leak information about test dataset
#scaled_data = scaler.fit_transform(dataset)

# %%
# Define train and test size
train_size = int(0.7 * len(univariate_df))
test_size = len(univariate_df) - train_size

# Set look back
look_back = 30

train_unscaled, test_unscaled = dataset[:train_size-look_back, :], dataset[train_size-look_back:, :]
train_scaled = scaler.fit_transform(train_unscaled)
test_scaled = scaler.transform(test_unscaled)

x_train, y_train = create_dataset_with_look_back(train_scaled, look_back)
x_test, y_test = create_dataset_with_look_back(test_scaled, look_back)

# Reshape input to be [samples, time steps, features]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

print("Train size: ", len(x_train), " test size: ", len(x_test))
# Out:
# Train size:  473  test size:  229

# %%
# Building the model
model = Sequential()
model.add(GRU(32, return_sequences=True, input_shape=(look_back, 1)))
model.add(GRU(32, return_sequences=True))
model.add(GRU(32, return_sequences=True))
model.add(GRU(32))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

model.fit(x_train, y_train, epochs=200, batch_size=32)

model.summary()
# Out:
# Epoch 1/200
# 15/15 [==============================] - 6s 33ms/step - loss: 0.0462
# Epoch 2/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0060
# Epoch 3/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0023
# Epoch 4/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0016
# Epoch 5/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0014
# Epoch 6/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0013
# Epoch 7/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0012
# Epoch 8/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0011
# Epoch 9/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0011
# Epoch 10/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0010
# Epoch 11/200
# 15/15 [==============================] - 0s 29ms/step - loss: 9.6534e-04
# Epoch 12/200
# 15/15 [==============================] - 0s 28ms/step - loss: 9.3053e-04
# Epoch 13/200
# 15/15 [==============================] - 0s 29ms/step - loss: 8.6312e-04
# Epoch 14/200
# 15/15 [==============================] - 0s 29ms/step - loss: 8.2925e-04
# Epoch 15/200
# 15/15 [==============================] - 0s 28ms/step - loss: 8.1857e-04
# Epoch 16/200
# 15/15 [==============================] - 0s 28ms/step - loss: 7.9658e-04
# Epoch 17/200
# 15/15 [==============================] - 0s 28ms/step - loss: 7.8940e-04
# Epoch 18/200
# 15/15 [==============================] - 0s 28ms/step - loss: 7.8068e-04
# Epoch 19/200
# 15/15 [==============================] - 0s 28ms/step - loss: 7.1052e-04
# Epoch 20/200
# 15/15 [==============================] - 0s 28ms/step - loss: 6.9066e-04
# Epoch 21/200
200
# 15/15 [==============================] - 0s 30ms/step - loss: 4.2630e-04
# Epoch 163/200
# 15/15 [==============================] - 0s 29ms/step - loss: 4.6985e-04
# Epoch 164/200
# 15/15 [==============================] - 0s 30ms/step - loss: 3.5269e-04
# Epoch 165/200
# 15/15 [==============================] - 0s 30ms/step - loss: 3.8240e-04
# Epoch 166/200
# 15/15 [==============================] - 0s 29ms/step - loss: 4.2623e-04
# Epoch 167/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.7742e-04
# Epoch 168/200
# 15/15 [==============================] - 0s 30ms/step - loss: 3.8342e-04
# Epoch 169/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.6675e-04
# Epoch 170/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.3639e-04
# Epoch 171/200
# 15/15 [==============================] - 0s 29ms/step - loss: 4.4493e-04
# Epoch 172/200
# 15/15 [==============================] - 0s 29ms/step - loss: 4.0371e-04
# Epoch 173/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.4555e-04
# Epoch 174/200
# 15/15 [==============================] - 0s 29ms/step - loss: 4.0283e-04
# Epoch 175/200
# 15/15 [==============================] - 0s 30ms/step - loss: 4.3839e-04
# Epoch 176/200
# 15/15 [==============================] - 0s 29ms/step - loss: 4.9377e-04
# Epoch 177/200
# 15/15 [==============================] - 0s 30ms/step - loss: 5.3053e-04
# Epoch 178/200
# 15/15 [==============================] - 0s 29ms/step - loss: 4.8108e-04
# Epoch 179/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.4420e-04
# Epoch 180/200
# 15/15 [==============================] - 0s 29ms/step - loss: 4.5422e-04
# Epoch 181/200
# 15/15 [==============================] - 0s 30ms/step - loss: 3.6474e-04
# Epoch 182/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.4770e-04
# Epoch 183/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.5070e-04
# Epoch 184/200
# 15/15 [==============================] - 0s 30ms/step - loss: 3.2528e-04
# Epoch 185/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.5415e-04
# Epoch 186/200
# 15/15 [==============================] - 0s 30ms/step - loss: 4.2400e-04
# Epoch 187/200
# 15/15 [==============================] - 0s 30ms/step - loss: 3.1501e-04
# Epoch 188/200
# 15/15 [==============================] - 0s 30ms/step - loss: 3.3211e-04
# Epoch 189/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.2788e-04
# Epoch 190/200
# 15/15 [==============================] - 0s 29ms/step - loss: 4.0318e-04
# Epoch 191/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.2712e-04
# Epoch 192/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.2005e-04
# Epoch 193/200
# 15/15 [==============================] - 0s 30ms/step - loss: 4.3134e-04
# Epoch 194/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.6069e-04
# Epoch 195/200
# 15/15 [==============================] - 1s 31ms/step - loss: 3.6444e-04
# Epoch 196/200
# 15/15 [==============================] - 0s 30ms/step - loss: 3.5877e-04
# Epoch 197/200
# 15/15 [==============================] - 0s 30ms/step - loss: 4.0171e-04
# Epoch 198/200
# 15/15 [==============================] - 0s 29ms/step - loss: 4.1908e-04
# Epoch 199/200
# 15/15 [==============================] - 0s 29ms/step - loss: 4.1807e-04
# Epoch 200/200
# 15/15 [==============================] - 0s 29ms/step - loss: 3.5346e-04
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_12 (GRU)                (None, 30, 32)            3360
#
#  gru_13 (GRU)                (None, 30, 32)            6336
#
#  gru_14 (GRU)                (None, 30, 32)            6336
#
#  gru_15 (GRU)                (None, 32)                6336
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 22,401
# Trainable params: 22,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Do predictions
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)

# Invert predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform([y_train])

test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# Calculate the scores
score_rmse = np.sqrt(mean_squared_error(y_test[0], test_predict[:,0]))
score_mae = mean_absolute_error(y_test[0], test_predict[:,0])
score_r2 = r2_score(y_test[0], test_predict[:, 0])
print('RMSE: {}, R2: {}'.format(score_rmse, score_r2))
# Out:
# 15/15 [==============================] - 1s 8ms/step
# 8/8 [==============================] - 0s 7ms/step
# RMSE: 1382.2328751582882, R2: 0.9786214251519869

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
x_train_ticks = univariate_df.head(train_size)['date']
y_train = univariate_df.head(train_size)['close']
x_test_ticks = univariate_df.tail(test_size)['date']

fig, ax = plt.subplots(1, figsize=(12, 6))
sns.lineplot(x=x_train_ticks, y=y_train, ax=ax, color=sns.color_palette("muted")[0], label='Train Set', alpha=0.7, linewidth=1.3)
sns.lineplot(x=x_train_ticks[look_back:-look_back], y=train_predict[:, 0], ax=ax, color=sns.color_palette("muted")[3], label='Train Prediction')
sns.lineplot(x=x_test_ticks, y=y_test[0], ax=ax, color=sns.color_palette("muted")[1], label='Ground truth', alpha=0.7, linewidth=1.3)
sns.lineplot(x=x_test_ticks, y=test_predict[:, 0], ax=ax, color=sns.color_palette("muted")[2], label='Prediction')

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}, R2: {score_r2:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='Close', fontsize=14)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [45], line 8
#       5 fig, ax = plt.subplots(1, figsize=(12, 6))
#       6 #sns.lineplot(x=x_train_ticks, y=y_train, ax=ax, color=sns.color_palette("muted")[0], label='Train Set', alpha=0.7, linewidth=1.3)
#       7 #sns.lineplot(x=x_train_ticks[look_back:-look_back], y=train_predict[:, 0], ax=ax, color=sns.color_palette("muted")[3], label='Train Prediction')
# ----> 8 sns.lineplot(x=x_test_ticks, y=y_test[0][:-100], ax=ax, color=sns.color_palette("muted")[1], label='Ground truth', alpha=0.7, linewidth=1.3)
#       9 sns.lineplot(x=x_test_ticks, y=test_predict[:-100, 0], ax=ax, color=sns.color_palette("muted")[2], label='Prediction')
#      11 ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}, R2: {score_r2:.2f}', fontsize=14)
#
# File ~/Library/Python/3.9/lib/python/site-packages/seaborn/relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
#     620     estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     621     sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     622     legend=legend,
#     623 )
#     625 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     626 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/Library/Python/3.9/lib/python/site-packages/seaborn/relational.py:365, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     351 def __init__(
#     352     self, *,
#     353     data=None, variables={},
#    (...)
#     359     # the kind of plot to draw, but for the time being we need to set
#     360     # this information so the SizeMapping can use it
#     361     self._default_size_range = (
#     362         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     363     )
# --> 365     super().__init__(data=data, variables=variables)
#     367     self.estimator = estimator
#     368     self.errorbar = errorbar
#
# File ~/Library/Python/3.9/lib/python/site-packages/seaborn/_oldcore.py:640, in VectorPlotter.__init__(self, data, variables)
#     635 # var_ordered is relevant only for categorical axis variables, and may
#     636 # be better handled by an internal axis information object that tracks
#     637 # such information and is set up by the scale_* methods. The analogous
#     638 # information for numeric axes would be information about log scales.
#     639 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640 self.assign_variables(data, variables)
#     642 for var, cls in self._semantic_mappings.items():
#     643
#     644     # Create the mapping function
#     645     map_func = partial(cls.map, plotter=self)
#
# File ~/Library/Python/3.9/lib/python/site-packages/seaborn/_oldcore.py:701, in VectorPlotter.assign_variables(self, data, variables)
#     699 else:
#     700     self.input_format = "long"
# --> 701     plot_data, variables = self._assign_variables_longform(
#     702         data, **variables,
#     703     )
#     705 self.plot_data = plot_data
#     706 self.variables = variables
#
# File ~/Library/Python/3.9/lib/python/site-packages/seaborn/_oldcore.py:962, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     958         variables[key] = getattr(val, "name", None)
#     960 # Construct a tidy plot DataFrame. This will convert a number of
#     961 # types automatically, aligning on index in case of pandas objects
# --> 962 plot_data = pd.DataFrame(plot_data)
#     964 # Reduce the variables dictionary to fields with valid data
#     965 variables = {
#     966     var: name
#     967     for var, name in variables.items()
#     968     if plot_data[var].notnull().any()
#     969 }
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
#     658         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     659     )
#     661 elif isinstance(data, dict):
#     662     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 663     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     664 elif isinstance(data, ma.MaskedArray):
#     665     import numpy.ma.mrecords as mrecords
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/internals/construction.py:494, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     490     else:
#     491         # dtype check to exclude e.g. range objects, scalars
#     492         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 494 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/internals/construction.py:119, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116 if verify_integrity:
#     117     # figure out the index, if necessary
#     118     if index is None:
# --> 119         index = _extract_index(arrays)
#     120     else:
#     121         index = ensure_index(index)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/internals/construction.py:681, in _extract_index(data)
#     676     if lengths[0] != len(index):
#     677         msg = (
#     678             f"array length {lengths[0]} does not match index "
#     679             f"length {len(index)}"
#     680         )
# --> 681         raise ValueError(msg)
#     682 else:
#     683     index = default_index(lengths[0])
#
# ValueError: array length 129 does not match index length 100

# %% [markdown]
# ### Stationary data

# %%
# Prepare data
univariate_df = bitcoin_dataframe[['date', 'close']].copy()

# 1st order differencing
univariate_df['close_diff_1'] = np.append([0], np.diff(univariate_df['close']))

close_only_df = univariate_df.filter(['close_diff_1'])
dataset = close_only_df.values

scaler = MinMaxScaler(feature_range=(0, 1))
#scaled_data = scaler.fit_transform(dataset)

# %%
# Define train and test size
train_size = int(0.7 * len(univariate_df))
test_size = len(univariate_df) - train_size

# Set look back
look_back = 30

train_unscaled, test_unscaled = dataset[:train_size-look_back, :], dataset[train_size-look_back:, :]
train_scaled = scaler.fit_transform(train_unscaled)
test_scaled = scaler.transform(test_unscaled)

x_train, y_train = create_dataset_with_look_back(train_scaled, look_back)
x_test, y_test = create_dataset_with_look_back(test_scaled, look_back)

# Reshape input to be [samples, time steps, features]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

print("Train size: ", len(x_train), " test size: ", len(x_test))
# Out:
# Train size:  473  test size:  229

# %%
# Building the model
model = Sequential()
model.add(GRU(32, return_sequences=True, input_shape=(look_back, 1)))
model.add(GRU(32, return_sequences=True))
model.add(GRU(32, return_sequences=True))
model.add(GRU(32))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

model.fit(x_train, y_train, epochs=200, batch_size=32)

model.summary()
# Out:
# Epoch 1/200
# 15/15 [==============================] - 7s 34ms/step - loss: 0.1231
# Epoch 2/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0179
# Epoch 3/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0099
# Epoch 4/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0082
# Epoch 5/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0079
# Epoch 6/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0081
# Epoch 7/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0080
# Epoch 8/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0080
# Epoch 9/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0080
# Epoch 10/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0080
# Epoch 11/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0081
# Epoch 12/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0080
# Epoch 13/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0079
# Epoch 14/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0079
# Epoch 15/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0080
# Epoch 16/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0082
# Epoch 17/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0080
# Epoch 18/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0080
# Epoch 19/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0081
# Epoch 20/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0080
# Epoch 21/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0080
# Epoch 22/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0079
# Epoch 23/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0080
# Epoch 24/200
# 15/15 [==============================] - 1s 36ms/step - loss: 0.0080
# Epoch 25/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0080
# Epoch 26/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0081
# Epoch 27/200
# 15/15 [==============================] - 1s 34ms/step - loss: 0.0082
# Epoch 28/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0080
# Epoch 29/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0082
# Epoch 30/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0079
# Epoch 31/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0081
# Epoch 32/200
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0083
# Epoch 33/200
# 15/15 [==============================] - 1s 38ms/step - loss: 0.0080
# Epoch 34/200
# 15/15 [==============================] - 1s 38ms/step - loss: 0.0081
# Epoch 35/200
# 15/15 [==============================] - 1s 61ms/step - loss: 0.0081
# Epoch 36/200
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0081
# Epoch 37/200
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0082
# Epoch 38/200
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0079
# Epoch 39/200
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0081
# Epoch 40/200
# 15/15 [==============================] - 1s 60ms/step - loss: 0.0080
# Epoch 41/200
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0079
# Epoch 42/200
# 15/15 [==============================] - 1s 54ms/step - loss: 0.
200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0078
# Epoch 157/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0078
# Epoch 158/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0081
# Epoch 159/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0078
# Epoch 160/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0077
# Epoch 161/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0077
# Epoch 162/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0077
# Epoch 163/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0083
# Epoch 164/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0078
# Epoch 165/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0078
# Epoch 166/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0078
# Epoch 167/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0075
# Epoch 168/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0076
# Epoch 169/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0075
# Epoch 170/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0076
# Epoch 171/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0080
# Epoch 172/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0078
# Epoch 173/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0075
# Epoch 174/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0075
# Epoch 175/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0076
# Epoch 176/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0075
# Epoch 177/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0076
# Epoch 178/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0078
# Epoch 179/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0078
# Epoch 180/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0075
# Epoch 181/200
# 15/15 [==============================] - 1s 32ms/step - loss: 0.0075
# Epoch 182/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0075
# Epoch 183/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0075
# Epoch 184/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0076
# Epoch 185/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0075
# Epoch 186/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0075
# Epoch 187/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0076
# Epoch 188/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0078
# Epoch 189/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0082
# Epoch 190/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0076
# Epoch 191/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0074
# Epoch 192/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0075
# Epoch 193/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0078
# Epoch 194/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0076
# Epoch 195/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0077
# Epoch 196/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0076
# Epoch 197/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0074
# Epoch 198/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0074
# Epoch 199/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0077
# Epoch 200/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0076
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_16 (GRU)                (None, 30, 32)            3360
#
#  gru_17 (GRU)                (None, 30, 32)            6336
#
#  gru_18 (GRU)                (None, 30, 32)            6336
#
#  gru_19 (GRU)                (None, 32)                6336
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 22,401
# Trainable params: 22,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Do predictions
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)

# Invert predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform([y_train])

test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# Calculate the scores
score_rmse = np.sqrt(mean_squared_error(y_test[0], test_predict[:,0]))
score_mae = mean_absolute_error(y_test[0], test_predict[:,0])
score_r2 = r2_score(y_test[0], test_predict[:, 0])
print('RMSE: {}, R2: {}'.format(score_rmse, score_r2))
# Out:
# 15/15 [==============================] - 1s 7ms/step
# 8/8 [==============================] - 0s 7ms/step
# RMSE: 1359.7909948546185, R2: -0.025629759971994348

# %%
x_train_ticks = univariate_df.head(train_size)['date']
y_train = univariate_df.head(train_size)['close_diff_1']
x_test_ticks = univariate_df.tail(test_size)['date']

fig, ax = plt.subplots(1, figsize=(12, 6))
sns.lineplot(x=x_train_ticks, y=y_train, ax=ax, color=sns.color_palette("muted")[0], label='Train Set', alpha=0.7, linewidth=1.3)
sns.lineplot(x=x_train_ticks[look_back:-look_back], y=train_predict[:, 0], ax=ax, color=sns.color_palette("muted")[3], label='Train Prediction')
sns.lineplot(x=x_test_ticks, y=y_test[0], ax=ax, color=sns.color_palette("muted")[1], label='Ground truth', alpha=0.7, linewidth=1.3)
sns.lineplot(x=x_test_ticks, y=test_predict[:, 0], ax=ax, color=sns.color_palette("muted")[2], label='Prediction')

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}, R2: {score_r2:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='Close (1st Order Differencing)', fontsize=14)
# Out:
# /var/folders/5d/h_8336656hb0sql9hqtn3m400000gn/T/ipykernel_63092/2646127335.py:7: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sns.lineplot(x=x_train_ticks[look_back:-look_back], y=train_predict[:, 0], ax=ax, color=sns.color_palette("muted")[3], label='Train Prediction')
# Text(0, 0.5, 'Close (1st Order Differencing)')

# %% [markdown]
# GRU also fails on Stationary data even though it performs well on Non-Stationary data
